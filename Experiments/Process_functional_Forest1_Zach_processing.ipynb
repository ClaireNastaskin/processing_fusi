# %%
# CELL 0 - Load data and set up analysis switches
from pathlib import Path
import fusiproc_utils2 as fu
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from nilearn.glm.first_level import FirstLevelModel
from nilearn import plotting, image

# -------- dataset paths -------
BASE = Path('/Users/clairenastaskin/data/sub-Forest002/ses-20260215/task_audio_ARIA')
RUN  = 'bbc3_pwd.nii.gz'
PWD  = BASE / RUN
SIDE = BASE / RUN.replace('_pwd.nii.gz', '_pwd.json')

# -------- analysis switches ----
CONF_USE = dict(
    motion_6      = False,     # translation/rotation 6 params
    motion_fsl24  = True,    # Friston24 (mutually exclusive with motion_6)
    extra_fd      = False,
    dvars_stdz    = False,
    tcompcor      = False,
)

# --- temporal smoothing ------------------------------------------------------
SMOOTH_METHOD  = "boxcar"          # {"none", "boxcar", "savgol"}
SMOOTH_WINDOW  = 3                 # for boxcar (odd)
SG_PARAMS      = dict(window=7, polyorder=2)       # Savitzky–Golay (odd) 

FD_THRESH     = 0.5          # mm
RADIUS_MM     = 50.0         # mm for FD sphere

# ---------------------------------------------------------------------------
# Build a short suffix that encodes the chosen method (+ key params)
# ---------------------------------------------------------------------------
if SMOOTH_METHOD == "none":
    smooth_tag = "_nosmooth"

elif SMOOTH_METHOD == "boxcar":
    smooth_tag = f"_boxcar{SMOOTH_WINDOW}"

elif SMOOTH_METHOD == "savgol":
    smooth_tag = f"_savgol{SG_PARAMS['window']}-{SG_PARAMS['polyorder']}"

else:
    raise ValueError(f"Unknown SMOOTH_METHOD: {SMOOTH_METHOD}")
# Out:
# /Users/clairenastaskin/Documents/Anise/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# CELL 1 - Mean image
from nilearn import image

img_subset = image.mean_img(PWD)
mean_img = image.mean_img(img_subset)  
mean_path = BASE / RUN.replace('_pwd.nii.gz', '_mean.nii.gz')
mean_img.to_filename(mean_path)
print(f"Mean image saved to {mean_path}")
# Out:
# /var/folders/50/vlgy95sd2d1d6w1_l8pgqd1c0000gn/T/ipykernel_11971/422955407.py:4: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   img_subset = image.mean_img(PWD)
# Mean image saved to /Users/clairenastaskin/data/sub-Forest002/ses-20260215/task_audio_ARIA/bbc3_mean.nii.gz
# /var/folders/50/vlgy95sd2d1d6w1_l8pgqd1c0000gn/T/ipykernel_11971/422955407.py:5: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   mean_img = image.mean_img(img_subset)

# %%
# CELL 2 - Global signal and motion detection
data, affine, _ = fu.load_fusi_nifti(PWD)
mask = fu.nan_mask(data)
mask_path = fu.save_nifti(mask.astype(np.uint8), affine,
                          PWD.with_name(RUN.replace('_pwd', '_mask')))

y_lim= None #(1.2e4, 1.8e4) # If we want to set the y-axis limits

gs = fu.global_signal(data)
fu.plot_global_signal(gs, BASE/"global_signal.png",y_lim)
import matplotlib.pyplot as plt

TR = fu.repetition_time(SIDE)
np.save(BASE / "t_r.npy", TR)
bad_gs, good_gs, fig = fu.detect_motion_via_global(gs, TR, k = 3.0, y_lim=y_lim)
fig.savefig(BASE/"global_signal_with_masked_frame.png")
skip = set(bad_gs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 13
#      10 fu.plot_global_signal(gs, BASE/"global_signal.png",y_lim)
#      11 import matplotlib.pyplot as plt
# ---> 13 TR = fu.repetition_time(SIDE)
#      14 np.save(BASE / "t_r.npy", TR)
#      15 bad_gs, good_gs, fig = fu.detect_motion_via_global(gs, TR, k = 3.0, y_lim=y_lim)
#
# File ~/Documents/Anise/Experiments/fusiproc_utils2.py:61, in repetition_time(json_path)
#      59 def repetition_time(json_path: Path) -> float:
#      60     with open(json_path) as f:
# ---> 61         frame_times = np.array(json.load(f)["VolumeTiming"])
#      62     return float(np.median(np.diff(frame_times)))
#
# KeyError: 'VolumeTiming'

# %%
# CELL 4 - Rigid registration
# ------------------------------------------------------------------
# Rigid registration
# ------------------------------------------------------------------
registration_path = BASE / "registration"

if not registration_path.exists():
    registration_path.mkdir(exist_ok=True)
    
    reg, rigid, metric, stop, kept_idx = fu.register_3d_image_stack(
            np.where(np.isfinite(data), data, 0),
            reference='median',
            spacing=np.linalg.norm(affine[:3, :3], axis=0),
            skip_indices=skip,
            mask=mask,
            verbose=True)

    # Save the registration outputs
    np.save(registration_path / "reg.npy", reg)
    np.save(registration_path / "rigid.npy", rigid)
    np.save(registration_path / "metric.npy", metric)
    np.save(registration_path / "stop.npy", stop)
    np.save(registration_path / "kept_idx.npy", kept_idx)
    np.save(registration_path / "skip.npy", skip)
    # ---- Doppler movie -------------------------------------------------
    html = fu.save_doppler_movie(reg, registration_path/"Doppler_movie_after_rigid_registration.mp4")
    html  # renders in Jupyter

else:
    reg = np.load(registration_path / "reg.npy")
    rigid = np.load(registration_path / "rigid.npy")
    metric = np.load(registration_path / "metric.npy")
    stop = np.load(registration_path / "stop.npy")
    kept_idx = np.load(registration_path / "kept_idx.npy")
# Out:
# [frame    0] metric = -5.936778e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.04116e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    1] metric = -8.262718e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (5.1648e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    2] metric = -6.982273e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (1.44554e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    3] metric = -6.495972e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (7.20104e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    4] metric = -7.195665e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.81816e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    5] metric = -7.184128e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (1.5342e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    6] metric = -6.086831e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (2.13336e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    7] metric = -5.877696e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (7.96363e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    8] metric = -8.313814e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.86683e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    9] metric = -7.922709e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 21 iterations. Gradient magnitude (7.87329e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   10] metric = -8.605107e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (1.76986e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   11] metric = -7.977446e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (5.21904e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   12] metric = -7.946251e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (7.5593e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   13] metric = -8.151575e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (1.55474e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   14] metric = -8.388273e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (1.65326e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   15] metric = -5.708657e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.72492e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   16] metric = -6.042505e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (1.95477e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   17] metric = -7.099642e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (2.86158e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   18] metric = -6.503693e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (3.324e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   19] metric = -7.631589e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (6.74602e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   20] metric = -8.440817e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (3.39419e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   21] metric = -8.449049e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (8.64288e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   23] metric = -8.334306e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.01453e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   24] metric = -8.572358e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.28344e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   25] metric = -8.349450e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 6 iterations. Gradient magnitude (6.94169e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   26] metric = -8.775598e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (8.19468e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   27] metric = -8.643397e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.07581e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   28] metric = -8.016125e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.44968e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   29] metric = -6.831358e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.64848e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   30] metric = -7.090648e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.62446e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   31] metric = -7.075537e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.78266e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   32] metric = -8.416831e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (8.49986e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   33] metric = -8.276540e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.04194e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   34] metric = -8.860562e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.23349e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   35] metric = -8.816023e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (4.41634e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   36] metric = -8.709265e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (6.86745e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   37] metric = -8.676912e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.9025e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   38] metric = -8.810940e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (3.77763e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   39] metric = -7.969129e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (4.56403e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   40] metric = -8.599188e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.31168e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   41] metric = -8.225730e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (2.9411e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   42] metric = -6.434920e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (6.48934e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   43] metric = -8.400564e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.80216e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   44] metric = -7.169465e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (5.06647e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   45] metric = -7.271529e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (1.06445e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   46] metric = -7.479652e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.01746e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   47] metric = -8.145389e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 4 iterations. Gradient magnitude (9.65538e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   48] metric = -8.924398e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (7.98229e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   49] metric = -8.760442e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.49727e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   50] metric = -8.929747e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.14519e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   51] metric = -8.618199e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (3.11937e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   52] metric = -8.972080e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (5.5295e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   53] metric = -8.118384e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.07173e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   54] metric = -8.922744e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (1.36681e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   55] metric = -8.740534e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (7.85095e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   56] metric = -6.192687e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (3.3621e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   57] metric = -6.170309e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (4.34978e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   58] metric = -7.432247e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (6.65714e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   59] metric = -8.649411e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.62611e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   60] metric = -7.931278e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 18 iterations. Gradient magnitude (9.16718e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   61] metric = -7.310869e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.66497e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   62] metric = -8.310419e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (3.61731e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   63] metric = -8.824324e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (1.52702e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   64] metric = -9.154871e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.75783e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   65] metric = -8.456979e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (3.70044e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   66] metric = -8.906670e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (8.68649e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   67] metric = -8.775684e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.30733e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   68] metric = -8.906164e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.77757e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   69] metric = -8.731253e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.03461e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   70] metric = -8.288437e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.28358e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   71] metric = -7.978906e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.81819e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   72] metric = -7.769387e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.03623e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   73] metric = -7.600226e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (5.73228e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   74] metric = -7.879125e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (6.36821e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   75] metric = -7.378434e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (5.57346e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   76] metric = -8.366623e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (5.09514e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   77] metric = -8.551699e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (5.40984e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   78] metric = -8.207175e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (5.24464e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   79] metric = -8.709997e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.46595e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   80] metric = -9.219913e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.18911e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   81] metric = -9.015482e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (5.68008e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   82] metric = -8.650065e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (8.06108e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   83] metric = -8.705076e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (4.35185e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   84] metric = -8.883137e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (2.17149e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   85] metric = -9.102386e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.94114e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   86] metric = -8.640186e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 20 iterations. Gradient magnitude (9.9581e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   87] metric = -8.804497e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 6 iterations. Gradient magnitude (6.86129e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   88] metric = -8.706404e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (5.49359e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   89] metric = -7.352791e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (7.95214e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   90] metric = -7.541472e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.32752e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   91] metric = -7.594299e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (5.33086e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   92] metric = -8.469278e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.31584e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   93] metric = -8.381442e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (9.17193e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   94] metric = -8.976997e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.40047e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   95] metric = -8.908435e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (5.3969e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   97] metric = -9.057531e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (5.43244e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   98] metric = -8.823579e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (9.16646e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   99] metric = -8.875428e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (5.99695e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  100] metric = -8.872854e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (6.28472e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  101] metric = -7.458118e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (4.69538e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  102] metric = -8.665742e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.63697e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  103] metric = -7.877170e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.97955e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  104] metric = -8.223589e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.44697e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  105] metric = -8.420120e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.32516e-06) is less than gradient magnitude tolerance (0.0001).
# [frame  106] metric = -7.469640e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (8.97399e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  107] metric = -8.921316e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.07776e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  108] metric = -9.056513e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.23257e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  109] metric = -8.954496e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.75893e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  110] metric = -9.138577e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (1.16531e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  111] metric = -8.162867e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (3.7825e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  112] metric = -9.020082e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.69137e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  113] metric = -9.067695e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (1.88957e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  114] metric = -8.365370e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (1.42921e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  115] metric = -8.343204e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (2.25968e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  116] metric = -8.550168e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.20024e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  117] metric = -8.032220e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (3.97714e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  119] metric = -8.783985e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (2.11304e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  120] metric = -8.718449e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (1.64137e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  121] metric = -8.733280e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.57266e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  122] metric = -8.506853e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (7.91716e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  123] metric = -8.682028e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 23 iterations. Gradient magnitude (9.61592e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  124] metric = -8.301752e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (8.62331e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  125] metric = -8.887627e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (8.25504e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  126] metric = -8.477695e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (7.4895e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  127] metric = -9.070097e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.12342e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  128] metric = -7.378061e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.29878e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  129] metric = -7.972689e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (9.91374e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  130] metric = -8.436998e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (2.139e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  131] metric = -6.813768e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (7.82874e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  132] metric = -7.150948e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.25352e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  133] metric = -8.500219e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (1.51855e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  134] metric = -8.359518e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (2.07921e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  135] metric = -9.093728e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (4.91812e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  136] metric = -8.991985e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (9.7988e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  137] metric = -9.028683e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.79311e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  138] metric = -9.000801e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.23025e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  139] metric = -8.565131e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (8.1638e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  140] metric = -8.852752e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.63635e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  141] metric = -8.435040e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 24 iterations. Gradient magnitude (7.59925e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  142] metric = -8.402830e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.24552e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  143] metric = -8.012296e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (2.64206e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  144] metric = -8.475043e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.57619e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  145] metric = -8.240653e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (1.45092e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  146] metric = -7.889408e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (6.61611e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  147] metric = -7.687947e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.1041e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  148] metric = -8.352137e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (6.64081e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  149] metric = -8.058019e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (6.81002e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  150] metric = -9.133659e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.56472e-06) is less than gradient magnitude tolerance (0.0001).
# [frame  151] metric = -8.437021e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (3.59281e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  152] metric = -8.591000e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.43705e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  153] metric = -8.511861e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (6.56313e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  154] metric = -8.730858e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (6.81766e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  157] metric = -8.666612e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.23824e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  158] metric = -8.382361e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.0299e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  159] metric = -8.587155e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (9.41672e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  161] metric = -8.111502e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (7.10588e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  162] metric = -8.900449e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.63147e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  163] metric = -8.532223e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (9.13526e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  164] metric = -9.110274e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (2.01836e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  165] metric = -8.254649e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (1.83686e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  166] metric = -8.748686e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (9.45896e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  167] metric = -8.921045e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.56796e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  168] metric = -8.505565e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (9.77902e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  169] metric = -8.249701e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 20 iterations. Gradient magnitude (9.70844e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  170] metric = -7.869779e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (7.43853e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  171] metric = -8.913177e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (3.25703e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  172] metric = -8.996023e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (3.01161e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  173] metric = -8.930048e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.36042e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  174] metric = -8.976742e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.37676e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  175] metric = -8.663225e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (4.0196e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  176] metric = -9.095141e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (5.54843e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  177] metric = -8.763461e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.1834e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  178] metric = -8.842370e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.21541e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  180] metric = -8.598657e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (8.14257e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  181] metric = -8.742364e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 18 iterations. Gradient magnitude (9.00281e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  182] metric = -8.760297e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (4.53259e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  183] metric = -9.071504e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.08895e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  184] metric = -9.029184e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.93734e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  185] metric = -9.052961e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.60532e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  186] metric = -8.865594e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.58886e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  187] metric = -8.878921e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (1.83244e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  188] metric = -8.511038e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.28922e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  189] metric = -8.900410e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.62629e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  190] metric = -8.491278e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (8.38874e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  191] metric = -8.998221e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (3.19345e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  192] metric = -8.730487e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.20608e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  194] metric = -7.815481e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 20 iterations. Gradient magnitude (8.70922e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  195] metric = -8.989474e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.78894e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  196] metric = -9.162245e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.70107e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  197] metric = -9.008796e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.96841e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  198] metric = -8.621288e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (7.34794e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  199] metric = -8.834321e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.54814e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  200] metric = -8.759112e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (1.15739e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  201] metric = -8.713662e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.38889e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  202] metric = -8.072641e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.55514e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  203] metric = -8.975072e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (8.95317e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  204] metric = -8.691611e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.72797e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  205] metric = -9.017230e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (4.17532e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  206] metric = -8.707882e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (2.98674e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  207] metric = -9.068588e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (2.90476e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  208] metric = -8.682173e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (5.96557e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  209] metric = -8.333336e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 19 iterations. Gradient magnitude (6.73647e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  210] metric = -8.894744e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (6.20625e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  211] metric = -8.456661e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 18 iterations. Gradient magnitude (8.18853e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  212] metric = -8.027723e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 20 iterations. Gradient magnitude (9.10366e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  214] metric = -8.445669e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.91132e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  215] metric = -8.854208e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (2.53376e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  216] metric = -8.409239e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.09872e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  217] metric = -9.136944e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (7.88317e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  218] metric = -8.223346e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (2.75022e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  219] metric = -8.570582e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (5.98673e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  220] metric = -8.867979e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.82056e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  222] metric = -8.558020e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.03591e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  225] metric = -8.450517e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (3.20282e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  226] metric = -8.919240e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (4.92455e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  228] metric = -7.763404e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (1.82361e-05) is less than gradient magnitude tolerance (0.0001).
# ...
# [frame  317] metric = -9.074558e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.56551e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  318] metric = -8.067778e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (7.21159e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  319] metric = -8.166382e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.94661e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  320] metric = -8.810188e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (3.74719e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  321] metric = -8.236983e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.71028e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  322] metric = -8.583717e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (3.94759e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  325] metric = -8.228367e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (9.06841e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  326] metric = -7.617060e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 34 iterations. Gradient magnitude (7.31683e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  327] metric = -8.261452e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (9.32692e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  328] metric = -8.835281e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (6.15937e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  329] metric = -8.470435e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.15934e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  330] metric = -8.442211e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.86445e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  331] metric = -7.825135e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.26282e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  332] metric = -8.529445e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.33568e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  333] metric = -8.589896e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.46522e-06) is less than gradient magnitude tolerance (0.0001).
# [frame  334] metric = -8.176286e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 7 iterations. Gradient magnitude (6.94758e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  335] metric = -9.026004e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (4.61182e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  336] metric = -8.551728e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.9429e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  337] metric = -8.022217e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 30 iterations. Gradient magnitude (7.32235e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  339] metric = -7.975812e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 27 iterations. Gradient magnitude (6.15694e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  340] metric = -8.519093e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 19 iterations. Gradient magnitude (9.90444e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  341] metric = -8.774923e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (6.9969e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  342] metric = -8.427725e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (7.20538e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  343] metric = -8.680157e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (7.76707e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  344] metric = -7.868013e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.275e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  345] metric = -8.291107e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.67743e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  346] metric = -7.012400e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 27 iterations. Gradient magnitude (9.67554e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  347] metric = -7.323485e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 24 iterations. Gradient magnitude (6.63476e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  349] metric = -8.636346e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (8.68234e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  350] metric = -9.118925e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (9.71379e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  351] metric = -8.935877e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (5.77775e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  352] metric = -9.056111e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.62609e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  353] metric = -9.074184e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.63971e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  354] metric = -8.555452e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.56751e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  355] metric = -8.331046e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (6.7004e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  356] metric = -7.119895e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (3.98005e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  357] metric = -8.750356e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.16163e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  358] metric = -8.031451e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (9.07466e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  359] metric = -8.756074e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.23279e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  360] metric = -8.559598e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (2.69358e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  361] metric = -8.975262e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (5.22686e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  362] metric = -8.371855e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (5.67833e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  363] metric = -7.723568e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 31 iterations. Gradient magnitude (7.85867e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  364] metric = -7.817284e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 36 iterations. Gradient magnitude (8.39989e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  365] metric = -7.917385e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (9.28147e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  366] metric = -8.075731e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (7.82009e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  367] metric = -7.339769e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (1.18486e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  368] metric = -7.806803e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.19065e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  369] metric = -7.863387e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.10767e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  370] metric = -9.171439e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (9.37845e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  371] metric = -7.407831e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 22 iterations. Gradient magnitude (9.7487e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  372] metric = -8.073494e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (9.96347e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  373] metric = -8.109643e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.53078e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  374] metric = -8.059765e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 18 iterations. Gradient magnitude (8.55022e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  375] metric = -8.957928e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.00524e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  376] metric = -8.075450e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 23 iterations. Gradient magnitude (8.98447e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  377] metric = -7.916639e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 25 iterations. Gradient magnitude (8.82982e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  378] metric = -8.790169e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.98308e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  379] metric = -7.821609e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 28 iterations. Gradient magnitude (9.99579e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  380] metric = -8.890002e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (6.23056e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  381] metric = -8.712971e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (7.549e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  382] metric = -7.872945e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (8.04308e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  383] metric = -8.543409e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (8.30404e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  384] metric = -9.004614e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (7.2167e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  385] metric = -8.859168e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.66967e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  386] metric = -8.683591e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (4.2497e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  387] metric = -7.304871e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 26 iterations. Gradient magnitude (9.32244e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  388] metric = -8.237490e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (8.20532e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  389] metric = -8.113907e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (6.2861e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  390] metric = -8.219779e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (2.42451e-05) is less than gradient magnitude tolerance (0.0001).
# /Users/clairenastaskin/Documents/Anise/Experiments/fusiproc_utils2.py:439: RuntimeWarning: divide by zero encountered in log10
#   data_db = 10*np.log10(reg_data)
# Animation size has reached 20985080 bytes, exceeding the limit of 20971520.0. If you're sure you want a larger animation embedded, set the animation.embed_limit rc parameter to a larger value (in MB). This and further frames will be dropped.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Cell 5 – FD outliers, censor list, NaN‑padding
# ─────────────────────────────────────────────────────────────────────────────
n_frames = data.shape[-1]

# 1. FD on the gap‑free series (after GS censoring) ---------------------------
fd = fu.framewise_displacement(rigid, radius_mm=RADIUS_MM)

fd_full = np.full(n_frames, np.nan)
fd_full[kept_idx] = fd

bad_fd = fu.plot_fd(fd_full, FD_THRESH, BASE/"framewise_displacement.png")
np.savetxt(BASE/"fd_over_0p5_indices.txt", bad_fd, fmt='%d')

# 2. update global censor list ------------------------------------------------
skip.update(int(i) for i in bad_fd)

# 3. remove newly censored frames from the registration outputs ---------------
keep_after_all = [i for i in kept_idx if i not in skip]     # T indices
sel            = np.isin(kept_idx, keep_after_all)          # boolean mask

reg_use    = reg[...,  sel]           # (x,y,z,T)
rigid_use  = rigid[:,  sel]           # (6,T)
metric_use = metric[   sel]           # (T,)
stop_use   = [s for s, ok in zip(stop, sel) if ok]

# 4. create full‑length NaN‑padded arrays ------------------------------------
retained = keep_after_all                                 # same T indices
reg_full, rigid_full, metric_full, stop_full = fu.reinstate_nans(
        reg_use, rigid_use, metric_use, stop_use,
        n_frames, retained)

fu.plot_registration_parameters(rigid_full, registration_path/"registration.png")

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Cell 6 – DVARS calculation and temporal CompCor (tCompCor) confounds
# ─────────────────────────────────────────────────────────────────────────────

# Save rigid registered data (after registration, before smoothing) as a Nifti file
reg_path = fu.save_nifti(reg.astype(np.float32), affine,
                         BASE/"fusi_data_rigid_reg.nii.gz")

# Calculate standardized DVARS, raw DVARS, and voxelwise DVARS from the registered Nifti
dvars_stdz, dvars_raw, dvars_vx = fu.calc_dvars(reg_path, mask_path)

# Plot the standardized DVARS with marked motion outliers
fu.plot_dvars(dvars_stdz, BASE/"dvars_rigid.png")

# Run tCompCor (temporal CompCor) if selected in configuration.
# This extracts confound timecourses from noise ROIs in the data for denoising.
tc_out = {}
if CONF_USE["tcompcor"]:
    tc_out = fu.run_tcompcor(reg_path, mask_path,
                             BASE/"confounds", n_components=6,
                             percentile_threshold=0.02, tr=TR)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Cell 7 – sample mask, temporal smoothing, confounds (length‑matched)
# ─────────────────────────────────────────────────────────────────────────────
good_all    = np.array(retained, dtype=int)   # final list of frames to keep
sample_mask = good_all                        # passed to Nilearn

# -- temporal smoothing -------------------------------------------------------
if   SMOOTH_METHOD == "none":
    smoothed = reg_full.copy()

elif SMOOTH_METHOD == "boxcar":
    # Apply boxcar (moving average) smoothing: replaces each frame with the average across a sliding window.
    smoothed = fu.boxcar_smooth(reg_full, SMOOTH_WINDOW)

elif SMOOTH_METHOD == "savgol":
    # Apply Savitzky-Golay filter (polynomial smoothing filter). This method smooths the data
    # by fitting successive sub-sets of adjacent frames with a low-degree polynomial.
    smoothed = fu.savgol_smooth(reg_full, **SG_PARAMS)


else:
    raise ValueError(f"Unknown SMOOTH_METHOD '{SMOOTH_METHOD}'")

clean_img = nib.Nifti1Image(np.nan_to_num(smoothed), affine)
clean_img.to_filename(BASE/"fusi_run_clean.nii.gz")
fu.save_nifti(np.mean(clean_img.get_fdata(), axis=-1), affine, BASE/"fusi_run_clean_mean.nii.gz")

# ------------------------------------------------------------------
# Build confounds – all arrays must have n_frames rows
# ------------------------------------------------------------------
conf_list = []

# ── Motion regressors ──────────────────────────────────────────────────────
motion_full = rigid_full.T.copy()          # (n_frames, 6) – tx,ty,tz,rotx,roty,rotz
motion_full[np.isnan(motion_full)] = 0

if CONF_USE["motion_fsl24"]:
    # --- FSL‑24 construction ---
    # Compute first derivative of motion parameters (frame-to-frame changes)
    deriv = np.vstack([np.zeros((1, 6)), np.diff(motion_full, axis=0)])
    # Compute quadratic terms (squares of parameters and derivatives)
    quad  = np.square(np.hstack([motion_full, deriv]))      # 12 quadratic terms

    # Concatenate original parameters, derivatives, and all quadratic terms to obtain 24 regressors
    fsl24 = np.hstack([motion_full, deriv, quad])           # 6 + 6 + 12 = 24
    labels = (
        [f"{p}"   for p in ("tx","ty","tz","rotx","roty","rotz")] +
        [f"d{p}"  for p in ("tx","ty","tz","rotx","roty","rotz")] +
        [f"{p}2"  for p in ("tx","ty","tz","rotx","roty","rotz")] +
        [f"d{p}2" for p in ("tx","ty","tz","rotx","roty","rotz")]
    )
    # Package FSL-24 regressors into DataFrame
    conf_list.append(pd.DataFrame(fsl24, columns=labels))

elif CONF_USE["motion_6"]:
    # Use original 6 motion parameters as regressors (translations and rotations)
    conf_list.append(pd.DataFrame(
        motion_full,
        columns=["tx", "ty", "tz", "rotx", "roty", "rotz"]
    ))
    
# Frame-wise displacement (FD): Measures the sum of absolute values of the differentiated realignment estimates. 
# Commonly used to identify volumes with excessive head motion.
if CONF_USE["extra_fd"]:
    fd_col = fd_full.copy()                   # already n_frames long
    fd_col[np.isnan(fd_col)] = 0              # replace any NaNs with 0
    conf_list.append(pd.DataFrame(fd_col, columns=["fd"]))

# DVARS (D temporal derivative VARiance): Measures the root mean square variance of the temporal derivative of each brain volume; 
# used to identify signal changes due to motion or signal artifacts.

if CONF_USE["dvars_stdz"]:
    dvars_full = np.full(n_frames, np.nan)
    dvars_full[kept_idx] = dvars_stdz         # use kept_idx (not retained_gs)
    dvars_full[np.isnan(dvars_full)] = 0      # replace any NaNs with 0
    conf_list.append(pd.DataFrame(dvars_full, columns=["dvars"]))

# tCompCor (temporal CompCor): Principal component analysis of noise regions (usually WM/CSF) for nuisance regression; 
# helps remove physiological or other noise that is not head motion.

if CONF_USE["tcompcor"]:
    comps = pd.read_csv(tc_out["components"], sep="\t").to_numpy()
    tcomp_full = np.full((n_frames, comps.shape[1]), 0.0)
    tcomp_full[kept_idx] = comps              # align with same time base
    conf_list.append(pd.DataFrame(
        tcomp_full, columns=[f"tCompCor{i:02d}" for i in range(comps.shape[1])]))


# -- final dataframe -----------------------------------------------------------
confounds_df = pd.concat(conf_list, axis=1)
# Out:
# /Users/clairenastaskin/Documents/Anise/Experiments/fusiproc_utils2.py:343: RuntimeWarning: Mean of empty slice
#   out[..., t] = np.nanmean(data[..., lo:hi], axis=3)

# %%
import pandas as pd
import os

if os.path.exists(BASE / 'task_events.tsv'):
    events = pd.read_csv(BASE/"task_events.tsv", sep='\t')
else:
    task_path = list(BASE.glob('*events.tsv'))[0]
    events = pd.read_csv(task_path, sep='\t')

# events = pd.read_csv(BASE/"task_events.tsv", sep='\t')
events["trial_type"]
# Out:
# 0        Right foot
# 1         Left foot
# 2      Lips licking
# 3     Right fingers
# 4      Left fingers
# 5      Lips licking
# 6         Left foot
# 7      Left fingers
# 8        Right foot
# 9     Right fingers
# 10    Right fingers
# 11       Right foot
# 12     Lips licking
# 13     Left fingers
# 14        Left foot
# 15    Right fingers
# 16     Lips licking
# 17       Right foot
# 18     Left fingers
# 19    Right fingers
# 20        Left foot
# 21     Lips licking
# 22     Left fingers
# 23       Right foot
# 24    Right fingers
# 25     Lips licking
# 26       Right foot
# 27        Left foot
# Name: trial_type, dtype: object

# %%
import json

reaction_time = 0.5  # typical reaction time assumed
with open(SIDE, 'r') as f:
    sidecar = json.load(f)


if os.path.exists(BASE / 'task_events.tsv'):
    events = pd.read_csv(BASE/"task_events.tsv", sep='\t')
else:
    task_path = list(BASE.glob('*events.tsv'))[0]
    events = pd.read_csv(task_path, sep='\t')

events["onset"] -= sidecar["VolumeTiming"][0]
events["onset"] += reaction_time

glm = FirstLevelModel(
        t_r=TR, hrf_model="glover", drift_model="cosine",
        high_pass=0.01, noise_model="ar1", standardize=True,
        smoothing_fwhm=2, mask_img=nib.Nifti1Image(mask.astype(np.uint8), affine))
glm.subject_data_ = clean_img
glm, design = fu.build_design_matrix(glm, events, confounds_df, sample_mask)
plotting.plot_design_matrix(design)
# Save design matrix to npz file
np.savez(BASE / "design_matrix.npz", design_matrix=design.values, column_names=design.columns)

contrasts = fu.localizer_contrasts(design)


mean_img = image.mean_img(clean_img, copy_header=True)

for name, vec in contrasts.items():
    if name.startswith(("drift_", "tx", "ty", "tz", "rot", "dt", "drot")):
        continue

    zmap = glm.compute_contrast(vec, output_type="z_score")

    # ----- build filenames ---------------------------------------------------
    stem = f"{name}{smooth_tag}_z_map"
    nii_out  = BASE / f"{stem}.nii.gz"
    png_out  = BASE / f"{stem}.png"
    # ------------------------------------------------------------------------

    zmap.to_filename(nii_out)
    plotting.plot_stat_map(
        zmap, bg_img=mean_img, threshold=3.1, display_mode="ortho",
        cut_coords=plotting.find_xyz_cut_coords(zmap, activation_threshold=3.1),
        black_bg=True, title=name
    ).savefig(png_out, dpi=300)

    plotting.show()
