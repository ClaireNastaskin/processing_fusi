# %%
# CELL 0 - Load data and set up analysis switches
from pathlib import Path
import fusiproc_utils2 as fu
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from nilearn.glm.first_level import FirstLevelModel
from nilearn import plotting, image

# -------- dataset paths -------
BASE = Path('/Users/clairenastaskin/data/sub-Forest001/2026-04-09/fusi/task-movements_run-003')
RUN  = 'sub-Forest001_ses-20260409_task-movements_run-003_pwd.nii.gz'
PWD  = BASE / RUN
SIDE = BASE / RUN.replace('_pwd.nii.gz', '_pwd.json')

# -------- analysis switches ----
CONF_USE = dict(
    motion_6      = False,     # translation/rotation 6 params
    motion_fsl24  = True,    # Friston24 (mutually exclusive with motion_6)
    extra_fd      = False,
    dvars_stdz    = False,
    tcompcor      = False,
)

# --- temporal smoothing ------------------------------------------------------
SMOOTH_METHOD  = "boxcar"          # {"none", "boxcar", "savgol"}
SMOOTH_WINDOW  = 3                 # for boxcar (odd)
SG_PARAMS      = dict(window=7, polyorder=2)       # Savitzky–Golay (odd) 

FD_THRESH     = 0.5          # mm
RADIUS_MM     = 50.0         # mm for FD sphere

# ---------------------------------------------------------------------------
# Build a short suffix that encodes the chosen method (+ key params)
# ---------------------------------------------------------------------------
if SMOOTH_METHOD == "none":
    smooth_tag = "_nosmooth"

elif SMOOTH_METHOD == "boxcar":
    smooth_tag = f"_boxcar{SMOOTH_WINDOW}"

elif SMOOTH_METHOD == "savgol":
    smooth_tag = f"_savgol{SG_PARAMS['window']}-{SG_PARAMS['polyorder']}"

else:
    raise ValueError(f"Unknown SMOOTH_METHOD: {SMOOTH_METHOD}")

# %%
# Global signal and motion detection
data, affine, _ = fu.load_fusi_nifti(PWD)
mask = fu.nan_mask(data)
mask_path = fu.save_nifti(mask.astype(np.uint8), affine,
                          PWD.with_name(RUN.replace('_pwd', '_mask')))

y_lim= None #(1.5e4, 3.5e4) # If we want to set the y-axis limits

gs = fu.global_signal(data)
fu.plot_global_signal(gs, BASE/"global_signal.png",y_lim)
import matplotlib.pyplot as plt

TR = fu.repetition_time(SIDE)
np.save(BASE / "t_r.npy", TR)
bad_gs, good_gs, fig = fu.detect_motion_via_global(gs, TR, k = 3.0, y_lim=y_lim)
fig.savefig(BASE/"global_signal_with_masked_frame.png")
skip = set(bad_gs)

# %%
#  Rigid registration

registration_path = BASE / "registration"

if not registration_path.exists():
    registration_path.mkdir(exist_ok=True)
    
    reg, rigid, metric, stop, kept_idx = fu.register_3d_image_stack(
            np.where(np.isfinite(data), data, 0),
            reference='median',
            spacing=np.linalg.norm(affine[:3, :3], axis=0),
            skip_indices=skip,
            mask=mask,
            verbose=True)

    # Save the registration outputs
    np.save(registration_path / "reg.npy", reg)
    np.save(registration_path / "rigid.npy", rigid)
    np.save(registration_path / "metric.npy", metric)
    np.save(registration_path / "stop.npy", stop)
    np.save(registration_path / "kept_idx.npy", kept_idx)
    np.save(registration_path / "skip.npy", skip)
    # ---- Doppler movie -------------------------------------------------
    html = fu.save_doppler_movie(reg, registration_path/"Doppler_movie_after_rigid_registration.mp4")
    html  # renders in Jupyter

else:
    reg = np.load(registration_path / "reg.npy")
    rigid = np.load(registration_path / "rigid.npy")
    metric = np.load(registration_path / "metric.npy")
    stop = np.load(registration_path / "stop.npy")
    kept_idx = np.load(registration_path / "kept_idx.npy")
# Out:
# [frame    0] metric = -7.768034e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (7.13418e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    1] metric = -7.774967e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (7.8848e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    2] metric = -7.788754e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (9.2715e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    3] metric = -7.792591e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.01905e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    4] metric = -7.773692e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.94423e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    5] metric = -7.822534e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.28817e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    6] metric = -7.804844e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (7.10124e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    7] metric = -7.780377e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (7.52586e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    8] metric = -7.801445e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.83242e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    9] metric = -7.811150e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (7.54947e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   10] metric = -7.769155e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.83715e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   11] metric = -7.754875e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.77406e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   12] metric = -7.805718e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.02365e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   13] metric = -7.755345e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.86459e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   14] metric = -7.782898e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (5.36194e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   15] metric = -7.805618e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (7.19678e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   16] metric = -7.833743e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.85649e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   17] metric = -7.866192e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (7.36169e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   18] metric = -7.866995e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.27633e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   19] metric = -7.881300e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (5.6718e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   20] metric = -7.878201e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.93634e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   21] metric = -7.863155e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.99779e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   22] metric = -7.833311e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.61675e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   23] metric = -7.829302e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (3.14313e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   25] metric = -7.868377e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.90031e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   26] metric = -7.895677e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (9.4916e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   27] metric = -7.896018e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (5.13133e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   28] metric = -7.896050e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.13857e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   29] metric = -7.880459e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (8.92278e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   30] metric = -7.936782e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (6.62197e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   31] metric = -7.895429e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (6.46479e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   32] metric = -7.880007e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.68159e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   33] metric = -7.915200e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (7.68699e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   34] metric = -7.968354e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.60016e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   35] metric = -7.910736e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.87043e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   36] metric = -7.906161e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (6.15398e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   37] metric = -7.914535e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (4.86717e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   38] metric = -7.916003e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.68833e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   39] metric = -7.891093e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (5.6869e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   40] metric = -7.953117e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (3.29606e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   41] metric = -7.897843e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (4.34668e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   42] metric = -7.900538e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (6.37022e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   43] metric = -7.975765e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.64589e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   44] metric = -7.934521e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (9.79421e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   45] metric = -7.934882e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.83651e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   46] metric = -7.978495e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (5.18181e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   47] metric = -7.958231e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (9.54514e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   48] metric = -7.901321e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.06714e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   49] metric = -7.967994e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (2.13513e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   50] metric = -7.999044e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (7.55048e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   51] metric = -7.976156e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (5.49313e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   52] metric = -7.910405e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (4.39658e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   53] metric = -7.921446e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.37636e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   54] metric = -7.943225e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (1.27045e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   55] metric = -7.978399e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.82668e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   56] metric = -7.951189e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 18 iterations. Gradient magnitude (3.61305e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   57] metric = -7.948178e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (3.62804e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   59] metric = -7.978274e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (9.56151e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   60] metric = -7.920926e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (6.9958e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   61] metric = -7.923529e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (2.29363e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   62] metric = -7.957681e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.93881e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   63] metric = -7.937023e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (3.51582e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   64] metric = -7.993578e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (2.48028e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   65] metric = -7.966081e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (2.81514e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   66] metric = -7.961990e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.736e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   67] metric = -7.990841e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.07042e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   68] metric = -7.958024e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (6.96358e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   69] metric = -7.990824e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (3.2669e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   70] metric = -7.989467e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (5.32877e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   71] metric = -7.963217e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.23031e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   72] metric = -8.021565e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (5.87871e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   73] metric = -8.016905e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.19018e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   74] metric = -8.000666e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.41616e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   75] metric = -8.007004e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (1.53836e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   76] metric = -7.931004e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.98983e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   77] metric = -7.956238e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 18 iterations. Gradient magnitude (6.56256e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   78] metric = -7.984120e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (6.59687e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   79] metric = -7.992151e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.96641e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   80] metric = -8.014480e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (5.72124e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   81] metric = -8.033739e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.76232e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   82] metric = -8.059251e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.10709e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   83] metric = -7.989330e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (9.87317e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   85] metric = -8.029086e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (6.21821e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   86] metric = -8.023435e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.91188e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   87] metric = -7.983547e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (7.90028e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   88] metric = -7.973299e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (2.8581e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   89] metric = -8.036213e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.07453e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   90] metric = -8.012581e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (2.49593e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   91] metric = -8.024979e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (8.51855e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   92] metric = -8.006066e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.48129e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   93] metric = -8.006047e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (6.32176e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   94] metric = -8.007046e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.47697e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   95] metric = -8.017374e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (5.38566e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   96] metric = -7.971740e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (3.69472e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   97] metric = -8.027456e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (3.0714e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   98] metric = -7.987291e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (5.64131e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   99] metric = -8.015702e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.2521e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  100] metric = -8.001166e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.17166e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  102] metric = -8.004862e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.03344e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  103] metric = -8.039505e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (6.42588e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  104] metric = -7.993306e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.53845e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  105] metric = -7.984800e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.42622e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  106] metric = -7.974148e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.92413e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  107] metric = -8.010942e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.56906e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  109] metric = -8.016762e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (1.49591e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  110] metric = -7.993537e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (3.26827e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  111] metric = -7.958662e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (4.60783e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  112] metric = -7.992414e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.36774e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  113] metric = -8.000196e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (7.14233e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  114] metric = -7.997924e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (1.5004e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  115] metric = -8.015345e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (4.20666e-06) is less than gradient magnitude tolerance (0.0001).
# [frame  116] metric = -7.978165e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (5.49135e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  117] metric = -7.975329e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.44556e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  118] metric = -7.954060e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (2.64493e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  119] metric = -7.983059e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.2239e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  121] metric = -8.003168e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.43748e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  122] metric = -7.985542e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (1.78093e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  123] metric = -8.001050e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (2.31521e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  124] metric = -8.011894e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.31045e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  125] metric = -7.965144e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (2.06849e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  126] metric = -7.999147e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (9.29423e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  127] metric = -8.007586e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 17 iterations. Gradient magnitude (2.69107e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  128] metric = -8.000372e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.31311e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  129] metric = -7.987875e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.61517e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  130] metric = -8.018865e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.07744e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  131] metric = -7.999861e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.11497e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  132] metric = -7.896574e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (7.95461e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  133] metric = -8.001286e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.31308e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  134] metric = -8.004052e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (9.91327e-06) is less than gradient magnitude tolerance (0.0001).
# [frame  135] metric = -7.999704e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (7.02413e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  136] metric = -8.027236e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (7.50276e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  137] metric = -8.029754e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 18 iterations. Gradient magnitude (1.2212e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  138] metric = -7.992788e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (1.18327e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  139] metric = -8.010583e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (4.24431e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  140] metric = -8.031823e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.58211e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  141] metric = -8.035445e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (1.48298e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  142] metric = -7.840138e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (2.57914e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  143] metric = -7.978762e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (7.77413e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  144] metric = -8.016845e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (3.32939e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  145] metric = -8.043362e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (5.71163e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  146] metric = -7.995830e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.51001e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  147] metric = -7.973189e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (1.90838e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  148] metric = -7.973768e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.39261e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  149] metric = -7.943847e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.6571e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  150] metric = -7.951827e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (7.57331e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  151] metric = -7.998136e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.36341e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  152] metric = -7.981140e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.58585e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  153] metric = -7.988875e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.32511e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  154] metric = -7.962341e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.97519e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  155] metric = -8.003762e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (1.4732e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  156] metric = -7.989031e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.83917e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  157] metric = -7.992687e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.86117e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  158] metric = -8.031741e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (8.74396e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  159] metric = -7.992682e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (5.98219e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  160] metric = -7.949301e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.8189e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  161] metric = -7.985650e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (7.26716e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  162] metric = -7.977949e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (2.86615e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  163] metric = -7.981231e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (5.1018e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  164] metric = -7.968525e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (5.04117e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  165] metric = -7.963941e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.82982e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  169] metric = -7.897880e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.91064e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  170] metric = -7.866246e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (9.99799e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  171] metric = -7.947288e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.71384e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  172] metric = -7.976424e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.25664e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  173] metric = -7.988936e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.84283e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  174] metric = -8.008723e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (5.82288e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  175] metric = -8.028914e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (4.31667e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  176] metric = -7.987214e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.83608e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  177] metric = -8.010935e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (5.62506e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  178] metric = -7.978842e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (6.84812e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  179] metric = -7.949513e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (1.57034e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  180] metric = -7.987271e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.17078e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  181] metric = -8.004794e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (7.59139e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  182] metric = -7.994491e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (8.26022e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  183] metric = -7.914415e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.16506e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  184] metric = -7.914036e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (5.52241e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  185] metric = -7.908444e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.84624e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  186] metric = -7.794453e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (3.05096e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  187] metric = -7.820018e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.22783e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  188] metric = -7.916865e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (8.21109e-05) is less than gradient magnitude tolerance (0.0001).
# /Users/clairenastaskin/Documents/Anise/Experiments/fusiproc_utils2.py:439: RuntimeWarning: divide by zero encountered in log10
#   data_db = 10*np.log10(reg_data)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Cell 5 – FD outliers, censor list, NaN‑padding
# ─────────────────────────────────────────────────────────────────────────────
n_frames = data.shape[-1]

# 1. FD on the gap‑free series (after GS censoring) ---------------------------
fd = fu.framewise_displacement(rigid, radius_mm=RADIUS_MM)

fd_full = np.full(n_frames, np.nan)
fd_full[kept_idx] = fd

bad_fd = fu.plot_fd(fd_full, FD_THRESH, BASE/"framewise_displacement.png")
np.savetxt(BASE/"fd_over_0p5_indices.txt", bad_fd, fmt='%d')

# 2. update global censor list ------------------------------------------------
skip.update(int(i) for i in bad_fd)

# 3. remove newly censored frames from the registration outputs ---------------
keep_after_all = [i for i in kept_idx if i not in skip]     # T indices
sel            = np.isin(kept_idx, keep_after_all)          # boolean mask

reg_use    = reg[...,  sel]           # (x,y,z,T)
rigid_use  = rigid[:,  sel]           # (6,T)
metric_use = metric[   sel]           # (T,)
stop_use   = [s for s, ok in zip(stop, sel) if ok]

# 4. create full‑length NaN‑padded arrays ------------------------------------
retained = keep_after_all                                 # same T indices
reg_full, rigid_full, metric_full, stop_full = fu.reinstate_nans(
        reg_use, rigid_use, metric_use, stop_use,
        n_frames, retained)

fu.plot_registration_parameters(rigid_full, registration_path/"registration.png")

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Cell 6 – DVARS calculation and temporal CompCor (tCompCor) confounds
# ─────────────────────────────────────────────────────────────────────────────

# Save rigid registered data (after registration, before smoothing) as a Nifti file
reg_path = fu.save_nifti(reg.astype(np.float32), affine,
                         BASE/"fusi_data_rigid_reg.nii.gz")

# Calculate standardized DVARS, raw DVARS, and voxelwise DVARS from the registered Nifti
dvars_stdz, dvars_raw, dvars_vx = fu.calc_dvars(reg_path, mask_path)

# Plot the standardized DVARS with marked motion outliers
fu.plot_dvars(dvars_stdz, BASE/"dvars_rigid.png")

# Run tCompCor (temporal CompCor) if selected in configuration.
# This extracts confound timecourses from noise ROIs in the data for denoising.
tc_out = {}
if CONF_USE["tcompcor"]:
    tc_out = fu.run_tcompcor(reg_path, mask_path,
                             BASE/"confounds", n_components=6,
                             percentile_threshold=0.02, tr=TR)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Cell 7 – sample mask, temporal smoothing, confounds (length‑matched)
# ─────────────────────────────────────────────────────────────────────────────
good_all    = np.array(retained, dtype=int)   # final list of frames to keep
sample_mask = good_all                        # passed to Nilearn

# -- temporal smoothing -------------------------------------------------------
if   SMOOTH_METHOD == "none":
    smoothed = reg_full.copy()

elif SMOOTH_METHOD == "boxcar":
    # Apply boxcar (moving average) smoothing: replaces each frame with the average across a sliding window.
    smoothed = fu.boxcar_smooth(reg_full, SMOOTH_WINDOW)

elif SMOOTH_METHOD == "savgol":
    # Apply Savitzky-Golay filter (polynomial smoothing filter). This method smooths the data
    # by fitting successive sub-sets of adjacent frames with a low-degree polynomial.
    smoothed = fu.savgol_smooth(reg_full, **SG_PARAMS)


else:
    raise ValueError(f"Unknown SMOOTH_METHOD '{SMOOTH_METHOD}'")

clean_img = nib.Nifti1Image(np.nan_to_num(smoothed), affine)
clean_img.to_filename(BASE/"fusi_run_clean.nii.gz")
fu.save_nifti(np.mean(clean_img.get_fdata(), axis=-1), affine, BASE/"fusi_run_clean_mean.nii.gz")

# ------------------------------------------------------------------
# Build confounds – all arrays must have n_frames rows
# ------------------------------------------------------------------
conf_list = []

# ── Motion regressors ──────────────────────────────────────────────────────
motion_full = rigid_full.T.copy()          # (n_frames, 6) – tx,ty,tz,rotx,roty,rotz
motion_full[np.isnan(motion_full)] = 0

if CONF_USE["motion_fsl24"]:
    # --- FSL‑24 construction ---
    # Compute first derivative of motion parameters (frame-to-frame changes)
    deriv = np.vstack([np.zeros((1, 6)), np.diff(motion_full, axis=0)])
    # Compute quadratic terms (squares of parameters and derivatives)
    quad  = np.square(np.hstack([motion_full, deriv]))      # 12 quadratic terms

    # Concatenate original parameters, derivatives, and all quadratic terms to obtain 24 regressors
    fsl24 = np.hstack([motion_full, deriv, quad])           # 6 + 6 + 12 = 24
    labels = (
        [f"{p}"   for p in ("tx","ty","tz","rotx","roty","rotz")] +
        [f"d{p}"  for p in ("tx","ty","tz","rotx","roty","rotz")] +
        [f"{p}2"  for p in ("tx","ty","tz","rotx","roty","rotz")] +
        [f"d{p}2" for p in ("tx","ty","tz","rotx","roty","rotz")]
    )
    # Package FSL-24 regressors into DataFrame
    conf_list.append(pd.DataFrame(fsl24, columns=labels))

elif CONF_USE["motion_6"]:
    # Use original 6 motion parameters as regressors (translations and rotations)
    conf_list.append(pd.DataFrame(
        motion_full,
        columns=["tx", "ty", "tz", "rotx", "roty", "rotz"]
    ))
    
# Frame-wise displacement (FD): Measures the sum of absolute values of the differentiated realignment estimates. 
# Commonly used to identify volumes with excessive head motion.
if CONF_USE["extra_fd"]:
    fd_col = fd_full.copy()                   # already n_frames long
    fd_col[np.isnan(fd_col)] = 0              # replace any NaNs with 0
    conf_list.append(pd.DataFrame(fd_col, columns=["fd"]))

# DVARS (D temporal derivative VARiance): Measures the root mean square variance of the temporal derivative of each brain volume; 
# used to identify signal changes due to motion or signal artifacts.

if CONF_USE["dvars_stdz"]:
    dvars_full = np.full(n_frames, np.nan)
    dvars_full[kept_idx] = dvars_stdz         # use kept_idx (not retained_gs)
    dvars_full[np.isnan(dvars_full)] = 0      # replace any NaNs with 0
    conf_list.append(pd.DataFrame(dvars_full, columns=["dvars"]))

# tCompCor (temporal CompCor): Principal component analysis of noise regions (usually WM/CSF) for nuisance regression; 
# helps remove physiological or other noise that is not head motion.

if CONF_USE["tcompcor"]:
    comps = pd.read_csv(tc_out["components"], sep="\t").to_numpy()
    tcomp_full = np.full((n_frames, comps.shape[1]), 0.0)
    tcomp_full[kept_idx] = comps              # align with same time base
    conf_list.append(pd.DataFrame(
        tcomp_full, columns=[f"tCompCor{i:02d}" for i in range(comps.shape[1])]))


# -- final dataframe -----------------------------------------------------------
confounds_df = pd.concat(conf_list, axis=1)
# Out:
# /Users/clairenastaskin/Documents/Anise/Experiments/fusiproc_utils2.py:343: RuntimeWarning: Mean of empty slice
#   out[..., t] = np.nanmean(data[..., lo:hi], axis=3)

# %%
import pandas as pd
import os

if os.path.exists(BASE / 'task_events.tsv'):
    events = pd.read_csv(BASE/"task_events.tsv", sep='\t')
else:
    task_path = list(BASE.glob('*events.tsv'))[0]
    events = pd.read_csv(task_path, sep='\t')

# events = pd.read_csv(BASE/"task_events.tsv", sep='\t')
events["trial_type"]
# Out:
# 0     skateboard_middle.js
# 1      skateboard_thumb.js
# 2       skateboard_ring.js
# 3      skateboard_pinky.js
# 4      skateboard_index.js
# 5      skateboard_pinky.js
# 6     skateboard_middle.js
# 7       skateboard_ring.js
# 8      skateboard_index.js
# 9      skateboard_thumb.js
# 10     skateboard_thumb.js
# 11     skateboard_pinky.js
# 12    skateboard_middle.js
# 13     skateboard_index.js
# 14      skateboard_ring.js
# 15     skateboard_pinky.js
# 16      skateboard_ring.js
# 17     skateboard_thumb.js
# 18    skateboard_middle.js
# 19     skateboard_index.js
# Name: trial_type, dtype: object

# %%
import json

reaction_time = 0.5  # typical reaction time assumed
with open(SIDE, 'r') as f:
    sidecar = json.load(f)


if os.path.exists(BASE / 'task_events.tsv'):
    events = pd.read_csv(BASE/"task_events.tsv", sep='\t')
else:
    task_path = list(BASE.glob('*events.tsv'))[0]
    events = pd.read_csv(task_path, sep='\t')

events["onset"] -= sidecar["VolumeTiming"][0]/2
events["onset"] += reaction_time

glm = FirstLevelModel(
        t_r=TR, hrf_model="glover", drift_model="cosine",
        high_pass=0.01, noise_model="ar1", standardize=True,
        smoothing_fwhm=2, mask_img=nib.Nifti1Image(mask.astype(np.uint8), affine))

glm, design = fu.build_design_matrix(glm, events, confounds_df, sample_mask, clean_img)
plotting.plot_design_matrix(design)
# Save design matrix to npz file
np.savez(BASE / "design_matrix.npz", design_matrix=design.values, column_names=design.columns)

contrasts = fu.localizer_contrasts(design)


mean_img = image.mean_img(clean_img, copy_header=True)

for name, vec in contrasts.items():
    if name.startswith(("drift_", "tx", "ty", "tz", "rot", "dt", "drot")):
        continue

    zmap = glm.compute_contrast(vec, output_type="z_score")

    # ----- build filenames ---------------------------------------------------
    stem = f"{name}{smooth_tag}_z_map"
    nii_out  = BASE / f"{stem}.nii.gz"
    png_out  = BASE / f"{stem}.png"
    # ------------------------------------------------------------------------

    zmap.to_filename(nii_out)
    plotting.plot_stat_map(
        zmap, bg_img=mean_img, threshold=3.1, display_mode="ortho",
        cut_coords=plotting.find_xyz_cut_coords(zmap, activation_threshold=3.1),
        black_bg=True, title=name
    ).savefig(png_out, dpi=300)

    plotting.show()
# Out:
# /Users/clairenastaskin/Documents/Anise/.venv/lib/python3.9/site-packages/nilearn/glm/first_level/experimental_paradigm.py:177: UserWarning: The following unexpected columns in events data will be ignored: response_time, control, task, late_start, early_finish
#   warnings.warn(

# %%
import numpy as np


def make_localizer_contrasts(design_matrix):
    """Return a dictionary of four contrasts, given the design matrix."""
    # first generate canonical contrasts
    contrast_matrix = np.eye(design_matrix.shape[1])
    contrasts = {
        column: contrast_matrix[i]
        for i, column in enumerate(design_matrix.columns)
    }

    contrasts["faces-scenes-scrambled"] = (
        contrasts["faces"] - contrasts["scenes"] -  contrasts["scrambled_faces"]
    )
    return contrasts

from nilearn.plotting import plot_contrast_matrix

contrasts = make_localizer_contrasts(design)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 20
#      16     return contrasts
#      18 from nilearn.plotting import plot_contrast_matrix
# ---> 20 contrasts = make_localizer_contrasts(design)
#
# Cell In[18], line 14, in make_localizer_contrasts(design_matrix)
#       7 contrast_matrix = np.eye(design_matrix.shape[1])
#       8 contrasts = {
#       9     column: contrast_matrix[i]
#      10     for i, column in enumerate(design_matrix.columns)
#      11 }
#      13 contrasts["faces-scenes-scrambled"] = (
# ---> 14     contrasts["faces"] - contrasts["scenes"] -  contrasts["scrambled_faces"]
#      15 )
#      16 return contrasts
#
# KeyError: 'faces'

# %%
from nilearn import plotting

first_level_model = glm
design_matrix = first_level_model.design_matrices_[0]
contrasts = make_localizer_contrasts(design_matrix)

skip_prefixes = ("tx", "ty", "tz", "rot", "dt", "drift", "drot")

for name, vec in contrasts.items():
    if name.startswith(skip_prefixes):
        continue

    zmap = first_level_model.compute_contrast(vec, output_type="z_score")

    # Save zmap as NIfTI file
    nii_out = BASE / f"{name}{smooth_tag}_z_map.nii.gz"
    zmap.to_filename(nii_out)

    plotting.plot_stat_map(
        zmap, bg_img=mean_img, threshold=3.1, display_mode="ortho",
        cut_coords=plotting.find_xyz_cut_coords(zmap, activation_threshold=3.1),
        black_bg=True, title=name
    )

    plotting.show()
