# %%
#  Load data and set up analysis switches
from pathlib import Path
import fusiproc_utils2 as fu
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from nilearn.glm.first_level import FirstLevelModel
from nilearn import plotting, image
from nilearn.signal import clean
from typing import List, Optional, Sequence, Tuple, Union


# -------- dataset paths -------
BASE = Path('/Users/clairenastaskin/data/sub-Forest001/2025-10-07/task-ev-003')
RUN  = 'sub-Forest001_ses-20251007_task-ev_run-003_pwd.nii.gz'
PWD  = BASE / RUN
SIDE = BASE / RUN.replace('_pwd.nii.gz', '_pwd.json')

# -------- analysis switches ----
CONF_USE = dict(
    motion_fsl24  = True,    # Friston24 (mutually exclusive with motion_6)
)

# --- temporal smoothing ------------------------------------------------------
SMOOTH_METHOD  = "none"          # {"none", "boxcar", "savgol"}
SMOOTH_WINDOW  = 3                 # if smoothing with boxcar (odd)

FD_THRESH     = 0.5          # mm
RADIUS_MM     = 50.0         # mm for FD sphere

# ---------------------------------------------------------------------------
# Build a short suffix that encodes the chosen method (+ key params)
# ---------------------------------------------------------------------------
if SMOOTH_METHOD == "none":
    smooth_tag = "_nosmooth"

elif SMOOTH_METHOD == "boxcar":
    smooth_tag = f"_boxcar{SMOOTH_WINDOW}"


def detect_motion_via_global(
        sig: np.ndarray, t_r: float, k: float = 4.0,
        high_pass: float = 0.01,
        y_lim: Optional[Tuple[float, float]] = None,
        frame_indices: Optional[np.ndarray] = None
) -> tuple[np.ndarray, np.ndarray, plt.Figure]:
    # High-pass filter (+ detrend) to remove slow drifts before thresholding
    sig_filt = clean(sig.reshape(-1, 1), detrend=True, high_pass=high_pass,
                     standardize=False, t_r=t_r).ravel()
    med = np.median(sig_filt)
    mad = np.median(np.abs(sig_filt - med))
    thr = med + k * mad
    bad = np.where(sig_filt > thr)[0]
    good = np.array([i for i in range(sig.size) if i not in bad], dtype=np.int64)

    x = frame_indices if frame_indices is not None else np.arange(len(sig))

    fig, axes = plt.subplots(1, 1, figsize=(10, 6), sharex=True)

    # Top panel: input signal with outlier markers
    axes.plot(x, sig)
    for f in bad:
        axes.axvline(x[f], ls='--', c='r', alpha=.3)
    axes.set_title("Global signal with motion outliers")
    axes.set_ylabel("Average Intensity")
    if y_lim:
        axes.set_ylim(y_lim[0], y_lim[1])

    fig.tight_layout()
    return bad, good, fig

# %%
#  Load data and plot raw global signal
data, affine, _ = fu.load_fusi_nifti(PWD)
mask = fu.nan_mask(data)
mask_path = fu.save_nifti(mask.astype(np.uint8), affine,
                          PWD.with_name(RUN.replace('_pwd', '_mask')))

y_lim = (1.4e4, 2e4)

gs = fu.global_signal(data)
TR = fu.repetition_time(SIDE)
np.save(BASE / "t_r.npy", TR)

fig, ax = plt.subplots(figsize=(10, 3))
ax.plot(gs)
ax.set_title("Raw global signal")
ax.set_xlabel("Frame #")
ax.set_ylabel("Average Intensity")
ax.set_ylim(y_lim[0], y_lim[1])
plt.tight_layout()
plt.show()

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Remove frames above an arbitrary intensity threshold
# ─────────────────────────────────────────────────────────────────────────────
INTENSITY_THRESH = 2e4   # <-- adjust this based on the raw plot above

bad_intensity = np.where(gs > INTENSITY_THRESH)[0]
skip = set(int(i) for i in bad_intensity)

print(f"Frames above {INTENSITY_THRESH:.1e}: {len(bad_intensity)}")
print(f"Frame indices: {bad_intensity}")

fig, ax = plt.subplots(figsize=(10, 3))
ax.plot(gs)
ax.axhline(INTENSITY_THRESH, ls='--', c='orange', label=f'threshold = {INTENSITY_THRESH:.1e}')
for f in bad_intensity:
    ax.axvline(f, ls='--', c='r', alpha=.3)
ax.set_title(f"Intensity threshold \u2013 {len(bad_intensity)} frames removed")
ax.set_xlabel("Frame #")
ax.set_ylabel("Average Intensity")
ax.set_ylim(y_lim[0], y_lim[1])
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Frames above 2.0e+04: 2
# Frame indices: [ 85 376]

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Motion outlier detection (on signal with extreme frames removed)
# ─────────────────────────────────────────────────────────────────────────────
keep_mask = np.ones(len(gs), dtype=bool)
keep_mask[list(skip)] = False
gs_clean = gs[keep_mask]
kept_frames = np.where(keep_mask)[0]

bad_clean, good_clean, fig = detect_motion_via_global(
    gs_clean, TR, k=3.0, frame_indices=kept_frames, y_lim=y_lim)

# Map back to original frame indices
bad_gs = kept_frames[bad_clean]
skip.update(int(i) for i in bad_gs)

fig.savefig(BASE / "global_signal_with_masked_frame.png")
print(f"Motion outlier frames: {len(bad_gs)}")
print(f"Total skipped frames (intensity + motion): {len(skip)}")
# Out:
# Motion outlier frames: 38
# Total skipped frames (intensity + motion): 40

# %%
#  Rigid registration
# ------------------------------------------------------------------
# Rigid registration
# ------------------------------------------------------------------
registration_path = BASE / "registration"

if not registration_path.exists():
    registration_path.mkdir(exist_ok=True)
    
    reg, rigid, metric, stop, kept_idx = fu.register_3d_image_stack(
            np.where(np.isfinite(data), data, 0),
            reference='median',
            spacing=np.linalg.norm(affine[:3, :3], axis=0),
            skip_indices=skip,
            mask=mask,
            verbose=True)

    # Save the registration outputs
    np.save(registration_path / "reg.npy", reg)
    np.save(registration_path / "rigid.npy", rigid)
    np.save(registration_path / "metric.npy", metric)
    np.save(registration_path / "stop.npy", stop)
    np.save(registration_path / "kept_idx.npy", kept_idx)
    np.save(registration_path / "skip.npy", skip)
    # ---- Doppler movie -------------------------------------------------
    html = fu.save_doppler_movie(reg, registration_path/"Doppler_movie_after_rigid_registration.mp4")
    html  # renders in Jupyter

else:
    reg = np.load(registration_path / "reg.npy")
    rigid = np.load(registration_path / "rigid.npy")
    metric = np.load(registration_path / "metric.npy")
    stop = np.load(registration_path / "stop.npy")
    kept_idx = np.load(registration_path / "kept_idx.npy")
# Out:
# [frame    0] metric = -8.983528e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (6.99872e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    1] metric = -9.348139e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (5.49559e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    2] metric = -9.407068e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (8.05533e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    3] metric = -9.376319e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.23256e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    4] metric = -9.373700e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (1.59605e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    5] metric = -9.404234e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (2.39556e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    6] metric = -9.387522e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (2.70509e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    7] metric = -9.421091e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (1.11067e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    8] metric = -9.427549e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.79329e-05) is less than gradient magnitude tolerance (0.0001).
# [frame    9] metric = -9.435826e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (7.72997e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   10] metric = -9.422023e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.53029e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   11] metric = -9.417945e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (7.84436e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   12] metric = -9.392203e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (3.54203e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   13] metric = -9.411114e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (2.127e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   14] metric = -9.426852e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (3.53014e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   15] metric = -9.398997e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (3.96818e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   16] metric = -9.417795e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (2.64779e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   17] metric = -9.371138e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 4 iterations. Gradient magnitude (4.83294e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   18] metric = -9.417701e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (1.41171e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   19] metric = -9.445183e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.16606e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   20] metric = -9.411356e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.86494e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   21] metric = -9.441805e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.0292e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   22] metric = -9.414750e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (2.83633e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   23] metric = -9.441841e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (4.34712e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   24] metric = -9.418426e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.64425e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   25] metric = -9.438092e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (5.30735e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   26] metric = -9.425723e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.00026e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   27] metric = -9.436726e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (1.10354e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   28] metric = -9.427324e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (2.50771e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   30] metric = -9.453958e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (3.39696e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   31] metric = -9.475736e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (6.16389e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   32] metric = -9.421459e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (2.23225e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   34] metric = -9.467170e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.68076e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   35] metric = -9.461268e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (4.24403e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   38] metric = -9.476158e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (1.32248e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   39] metric = -9.477684e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (8.84018e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   40] metric = -9.459664e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.51333e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   41] metric = -9.454394e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (7.19982e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   42] metric = -9.452232e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.77395e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   43] metric = -9.474144e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (4.8484e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   44] metric = -9.453049e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (1.64258e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   45] metric = -9.466713e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (8.32521e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   46] metric = -9.452776e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (3.90711e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   47] metric = -9.461509e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (2.95889e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   48] metric = -9.455517e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (8.03012e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   49] metric = -9.475887e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (8.83193e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   50] metric = -9.410065e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (5.74999e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   51] metric = -9.448846e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (9.53333e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   52] metric = -9.441727e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (5.46994e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   53] metric = -9.487854e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (6.91277e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   54] metric = -9.465305e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (9.6524e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   55] metric = -9.454990e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (2.89874e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   56] metric = -9.451331e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.5664e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   57] metric = -9.461366e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (7.87301e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   58] metric = -9.455825e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (7.75762e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   59] metric = -9.478410e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (3.73488e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   60] metric = -9.462853e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (9.70749e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   61] metric = -9.481823e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.3786e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   62] metric = -9.443745e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.59286e-05) is less than gradient magnitude tolerance (0.0001).
# [frame   63] metric = -9.476665e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 15 iterations. Gradient magnitude (6.70501e-06) is less than gradient magnitude tolerance (0.0001).
# [frame   64] metric = -9.477409e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude
-05) is less than gradient magnitude tolerance (0.0001).
# [frame  428] metric = -9.436490e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (5.92485e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  429] metric = -9.415080e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (2.75088e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  430] metric = -9.373981e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (6.57191e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  431] metric = -9.421321e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.37846e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  432] metric = -9.377417e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (2.61262e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  433] metric = -9.383690e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (8.59594e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  434] metric = -9.388474e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.91379e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  435] metric = -9.433277e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (2.57401e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  436] metric = -9.424502e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (6.47525e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  438] metric = -9.407776e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 14 iterations. Gradient magnitude (1.57793e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  439] metric = -9.382744e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 16 iterations. Gradient magnitude (1.29683e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  442] metric = -9.401634e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.62988e-06) is less than gradient magnitude tolerance (0.0001).
# [frame  443] metric = -9.424963e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (1.86019e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  444] metric = -9.436498e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (2.86054e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  445] metric = -9.446866e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 9 iterations. Gradient magnitude (5.14321e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  446] metric = -9.451705e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (4.90032e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  447] metric = -9.396654e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (8.27907e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  448] metric = -9.412898e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (3.38289e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  449] metric = -9.337218e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (2.67811e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  451] metric = -9.419353e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (2.89018e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  452] metric = -9.446304e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 8 iterations. Gradient magnitude (8.19921e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  453] metric = -9.444464e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (9.88582e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  454] metric = -9.463772e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (3.65411e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  456] metric = -9.323344e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (9.17168e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  457] metric = -9.392927e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 10 iterations. Gradient magnitude (4.18195e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  458] metric = -9.393810e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 11 iterations. Gradient magnitude (4.41862e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  461] metric = -9.351638e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (4.42727e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  462] metric = -9.386452e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (7.00444e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  463] metric = -9.379635e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (1.88265e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  464] metric = -9.373597e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (2.00581e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  465] metric = -9.391694e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (4.61059e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  466] metric = -9.436522e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 12 iterations. Gradient magnitude (9.07097e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  467] metric = -9.418854e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (6.31399e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  468] metric = -9.429869e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (1.1999e-05) is less than gradient magnitude tolerance (0.0001).
# [frame  469] metric = -9.427531e-01 | stop: RegularStepGradientDescentOptimizerv4: Gradient magnitude tolerance met after 13 iterations. Gradient magnitude (2.24371e-05) is less than gradient magnitude tolerance (0.0001).
# /Users/clairenastaskin/Documents/Anise/Experiments/fusiproc_utils2.py:439: RuntimeWarning: divide by zero encountered in log10
#   data_db = 10*np.log10(reg_data)
# Animation size has reached 21055543 bytes, exceeding the limit of 20971520.0. If you're sure you want a larger animation embedded, set the animation.embed_limit rc parameter to a larger value (in MB). This and further frames will be dropped.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Cell 5 – FD outliers, censor list, NaN‑padding
# ─────────────────────────────────────────────────────────────────────────────
n_frames = data.shape[-1]

# 1. FD on the gap‑free series (after GS censoring) ---------------------------
fd = fu.framewise_displacement(rigid, radius_mm=RADIUS_MM)

fd_full = np.full(n_frames, np.nan)
fd_full[kept_idx] = fd

bad_fd = fu.plot_fd(fd_full, FD_THRESH, BASE/"framewise_displacement.png")
np.savetxt(BASE/"fd_over_0p5_indices.txt", bad_fd, fmt='%d')

# 2. update global censor list ------------------------------------------------
skip.update(int(i) for i in bad_fd)

# 3. remove newly censored frames from the registration outputs ---------------
keep_after_all = [i for i in kept_idx if i not in skip]     # T indices
sel            = np.isin(kept_idx, keep_after_all)          # boolean mask

reg_use    = reg[...,  sel]           # (x,y,z,T)
rigid_use  = rigid[:,  sel]           # (6,T)
metric_use = metric[   sel]           # (T,)
stop_use   = [s for s, ok in zip(stop, sel) if ok]

# 4. create full‑length NaN‑padded arrays ------------------------------------
retained = keep_after_all                                 # same T indices
reg_full, rigid_full, metric_full, stop_full = fu.reinstate_nans(
        reg_use, rigid_use, metric_use, stop_use,
        n_frames, retained)

fu.plot_registration_parameters(rigid_full, registration_path/"registration.png")

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Sample mask, temporal smoothing, confounds (length‑matched)
# ─────────────────────────────────────────────────────────────────────────────
good_all    = np.array(retained, dtype=int)   # final list of frames to keep
sample_mask = good_all                        # passed to Nilearn

# -- temporal smoothing -------------------------------------------------------
if   SMOOTH_METHOD == "none":
    smoothed = reg_full.copy()

elif SMOOTH_METHOD == "boxcar":
    # Apply boxcar (moving average) smoothing: replaces each frame with the average across a sliding window.
    smoothed = fu.boxcar_smooth(reg_full, SMOOTH_WINDOW)


clean_img = nib.Nifti1Image(np.nan_to_num(smoothed), affine)
clean_img.to_filename(BASE/"fusi_run_clean.nii.gz")
fu.save_nifti(np.mean(clean_img.get_fdata(), axis=-1), affine, BASE/"fusi_run_clean_mean.nii.gz")
# Out:
# PosixPath('/Users/clairenastaskin/data/sub-Forest001/2025-10-07/task-ev-003/fusi_run_clean_mean.nii.gz')

# %%
# Voxelwise high-pass filter (cutoff = 0.01 Hz)

from nilearn.signal import clean as signal_clean

fusi_data = clean_img.get_fdata()                        # (x, y, z, T)
nx, ny, nz, nt = fusi_data.shape

# Extract only retained frames (avoid filtering the zero-padded gaps)
good_data = fusi_data[..., sample_mask]                  # (x, y, z, n_good)

# Reshape to (n_good, n_voxels) – the layout nilearn.signal.clean expects
voxels_2d = good_data.reshape(-1, len(sample_mask)).T    # (n_good, n_voxels)

# High-pass filter each voxel's timeseries at 0.01 Hz
filtered_2d = signal_clean(voxels_2d, high_pass=0.01, t_r=TR, detrend=False)

# Place filtered frames back into the full-length array
filtered_data = np.zeros_like(fusi_data)
filtered_data[..., sample_mask] = filtered_2d.T.reshape(nx, ny, nz, len(sample_mask))

# Update clean_img 
clean_img = nib.Nifti1Image(filtered_data, affine)
clean_img.to_filename(BASE / "fusi_run_clean_highpass.nii.gz")
print(f"High-pass filtered data saved – {len(sample_mask)} retained frames, cutoff = 0.01 Hz")

global_mean_filtered = np.mean(filtered_data, axis=(0,1,2))
fig, ax = plt.subplots()
ax.plot(sample_mask, global_mean_filtered[sample_mask], linewidth=0.8)
ax.set_xlabel("Frame index")
ax.set_ylabel("Global mean signal (high-pass filtered) after registration")
fig.savefig(BASE / "filtered_global_mean.png", dpi=150)
plt.show()
# Out:
# /var/folders/50/vlgy95sd2d1d6w1_l8pgqd1c0000gn/T/ipykernel_2433/2866456636.py:15: DeprecationWarning: The default strategy for standardize is currently 'zscore' which incorrectly uses population std to calculate sample zscores. The new strategy 'zscore_sample' corrects this behavior by using the sample std. In release 0.13, the default strategy will be replaced by the new strategy and the 'zscore' option will be removed. Please use 'zscore_sample' instead.
#   filtered_2d = signal_clean(voxels_2d, high_pass=0.01, t_r=TR, detrend=False)
# High-pass filtered data saved – 430 retained frames, cutoff = 0.01 Hz

# %%
# Import events.tsv 
import pandas as pd
import os

if os.path.exists(BASE / 'task_events.tsv'):
    events = pd.read_csv(BASE/"task_events.tsv", sep='\t')
else:
    task_path = list(BASE.glob('*events.tsv'))[0]
    events = pd.read_csv(task_path, sep='\t')

# events = pd.read_csv(BASE/"task_events.tsv", sep='\t')
events["trial_type"]
# Out:
# 0    avsnr150s24fps_hd.mp4
# 1    avsnr150s24fps_hd.mp4
# 2    avsnr150s24fps_hd.mp4
# 3    avsnr150s24fps_hd.mp4
# 4    avsnr150s24fps_hd.mp4
# Name: trial_type, dtype: object

# %%
# Explainable Variance – segment epochs

import json

with open(SIDE, 'r') as f:
    sidecar = json.load(f)
vol_times = np.array(sidecar["VolumeTiming"])

# Load BBC events (6 repetitions)
ev_dir = BASE 
ev_path = list(ev_dir.glob('*events.tsv'))[0]
bbc_events = pd.read_csv(ev_path, sep='\t')
print(bbc_events[['onset', 'duration', 'trial_type']].to_string())
print()

# For each BBC block, find the closest fUSI volume to the onset/offset
epochs = []
for _, row in bbc_events.iterrows():
    onset  = row['onset']
    offset = onset + row['duration']
    start_idx = np.argmin(np.abs(vol_times - onset))
    end_idx   = np.argmin(np.abs(vol_times - offset))
    epochs.append((start_idx, end_idx))
    print(f"  Onset {onset:8.1f}s → vol {start_idx:5d} (t={vol_times[start_idx]:.1f}s)  |  "
          f"Offset {offset:8.1f}s → vol {end_idx:5d} (t={vol_times[end_idx]:.1f}s)  |  "
          f"n_vols = {end_idx - start_idx}")

n_vols_per_epoch = min(end - start for start, end in epochs)
print(f"\nUsing {n_vols_per_epoch} volumes per epoch (trimmed to shortest)")
# Out:
#        onset  duration             trial_type
# 0    7.51004   150.022  avsnr150s24fps_hd.mp4
# 1  174.08204   150.029  avsnr150s24fps_hd.mp4
# 2  341.59504   150.028  avsnr150s24fps_hd.mp4
# 3  510.55904   150.019  avsnr150s24fps_hd.mp4
# 4  678.83204   150.001  avsnr150s24fps_hd.mp4
#
#   Onset      7.5s → vol     3 (t=7.4s)  |  Offset    157.5s → vol    86 (t=157.2s)  |  n_vols = 83
#   Onset    174.1s → vol    95 (t=173.4s)  |  Offset    324.1s → vol   178 (t=323.4s)  |  n_vols = 83
#   Onset    341.6s → vol   188 (t=341.4s)  |  Offset    491.6s → vol   271 (t=491.4s)  |  n_vols = 83
#   Onset    510.6s → vol   282 (t=511.2s)  |  Offset    660.6s → vol   365 (t=661.2s)  |  n_vols = 83
#   Onset    678.8s → vol   375 (t=679.2s)  |  Offset    828.8s → vol   458 (t=829.2s)  |  n_vols = 83
#
# Using 83 volumes per epoch (trimmed to shortest)

# %%
# Explainable Variance 
import scipy.stats

nx, ny, nz, nt = reg_full.shape

# 1. Voxel mask: voxels that are ALWAYS inside the FOV across all retained frames
#    (border voxels that move in/out during registration are excluded)
retained_data = reg_full[..., sample_mask]
voxel_mask = np.all(np.isfinite(retained_data), axis=-1)   # (nx, ny, nz)
valid_idx  = np.where(voxel_mask.ravel())[0]
n_valid    = len(valid_idx)
print(f"Valid voxels (always inside FOV): {n_valid} / {nx*ny*nz}")

# 2. Extract epochs – only valid voxels (memory efficient)
N_rep = len(epochs)
Y = np.empty((N_rep, n_vols_per_epoch, n_valid))
for i, (start, _) in enumerate(epochs):
    epoch_data = reg_full[..., start:start + n_vols_per_epoch]   # (nx,ny,nz,n_vols)
    Y[i] = epoch_data.reshape(-1, n_vols_per_epoch)[valid_idx].T # (n_vols, n_valid)

# 3. Valid timepoints: not a skipped frame in ANY of the 6 task repeats
time_valid = np.all(np.isfinite(Y), axis=(0, 2))   # (n_vols_per_epoch,)
Y_ev = Y[:, time_valid, :]                          # (N_rep, T_valid, V)
Y_ev = scipy.stats.zscore(Y_ev, axis=1)             # z-score across timepoints within each epoch (for EV calculation)
print(f"Valid timepoints per epoch: {time_valid.sum()} / {n_vols_per_epoch}")
print(f"Y_ev shape: {Y_ev.shape}  (repeats x timepoints x voxels)")

# 4. Explainable variance
mean_response = Y_ev.mean(axis=0)                                # (T, V)
var_mean_response = np.var(mean_response, axis=0)                # (V,)
var_responses = np.var(Y_ev, axis=1)                             # (N, V)
mean_var_responses = np.mean(var_responses, axis=0)              # (V,)

## Calculating EV using Sahani & Linden (2003) formula: EV = (N * var(mean_response) - mean(var(responses))) / (N - 1)
# ev_sahani = 1 / (N_rep - 1) * (N_rep * var_mean_response - mean_var_responses) #(V,)
# ev_sahani = ev_sahani / mean_var_responses # Normalized fraction (values between -1 and +1, or more typically 0 and 1), divide by the total variance:
## Map back to full volume
# ev_sahani_vol = np.full(nx * ny * nz, np.nan)
# ev_sahani_vol[valid_idx] = ev_sahani
# ev_sahani_vol = ev_sahani_vol.reshape(nx, ny, nz)
# print(f"\nEV  min: {np.nanmin(ev_sahani_vol):.4f}   median: {np.nanmedian(ev_sahani_vol):.4f}   max: {np.nanmax(ev_sahani_vol):.4f}")

## Calculating EV using Gallant lab method (ratio + bias correction, ddof=1)
mean_var = Y_ev.var(axis=1, dtype=np.float64, ddof=1).mean(axis=0)         # (V,)
var_mean = Y_ev.mean(axis=0).var(axis=0, dtype=np.float64, ddof=1)         # (V,)

ev_gallant = var_mean / mean_var                                           # (V,)
ev_gallant = ev_gallant - (1 - ev_gallant) / (N_rep - 1)                   # bias correction

ev_gallant_vol = np.full(nx * ny * nz, np.nan)
ev_gallant_vol[valid_idx] = ev_gallant
ev_gallant_vol = ev_gallant_vol.reshape(nx, ny, nz)

ev_vol = ev_gallant_vol
ev = ev_gallant

print(f"\nEV  min: {np.nanmin(ev):.4f}   median: {np.nanmedian(ev):.4f}   max: {np.nanmax(ev):.4f}")
# Out:
# Valid voxels (always inside FOV): 173242 / 173242
# Valid timepoints per epoch: 55 / 83
# Y_ev shape: (5, 55, 173242)  (repeats x timepoints x voxels)
#
# EV  min: -0.1418   median: 0.0098   max: 0.2331

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Explainable Variance – save and plot
# ─────────────────────────────────────────────────────────────────────────────

# Save EV map as NIfTI and numpy
ev_img = nib.Nifti1Image(ev_vol, affine)
ev_img.to_filename(BASE / "explainable_variance_map.nii.gz")
np.save(BASE / "explainable_variance_map.npy", ev_vol)
print(f"Saved: {BASE / 'explainable_variance_map.nii.gz'}")
print(f"Saved: {BASE / 'explainable_variance_map.npy'}")

# ── Slice views ──────────────────────────────────────────────────────────────
mean_data = nib.load(BASE / "fusi_run_clean_mean.nii.gz").get_fdata()
mid_z = nz // 2

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].imshow(mean_data[:, :, mid_z].T, origin='lower', cmap='gray', aspect='auto')
axes[0].set_title("Mean fUSI")

im1 = axes[1].imshow(ev_vol[:, :, mid_z].T, origin='lower', cmap='hot',
                      vmin=0, vmax=0.5, aspect='auto')
axes[1].set_title("Explainable Variance")
plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

axes[2].imshow(mean_data[:, :, mid_z].T, origin='lower', cmap='gray', aspect='auto')
im2 = axes[2].imshow(ev_vol[:, :, mid_z].T, origin='lower', cmap='hot',
                      alpha=0.6, vmin=0, vmax=0.5, aspect='auto')
axes[2].set_title("EV overlaid on mean")
plt.colorbar(im2, ax=axes[2], fraction=0.046, pad=0.04)

for ax in axes:
    ax.set_xlabel("X"); ax.set_ylabel("Y")
fig.suptitle(f"Explainable Variance  (z={mid_z}, {N_rep} repeats, "
             f"{time_valid.sum()} timepoints)", fontsize=13)
fig.tight_layout()
fig.savefig(BASE / "explainable_variance_map.png", dpi=300)
plt.show()

# ── Histogram ────────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(ev, bins=np.linspace(0, 0.5, 100), log=True, edgecolor='none')
ax.set_xlabel("Explainable Variance")
ax.set_ylabel("Number of voxels")
ax.set_title(f"EV distribution  ({n_valid} voxels)")
ax.axvline(np.nanmedian(ev), ls='--', c='r',
           label=f'median = {np.nanmedian(ev):.3f}')
ax.legend()
fig.tight_layout()
fig.savefig(BASE / "explainable_variance_histogram.png", dpi=150)
plt.show()
# Out:
# Saved: /Users/clairenastaskin/data/sub-Forest001/2025-10-07/task-ev-003/explainable_variance_map.nii.gz
# Saved: /Users/clairenastaskin/data/sub-Forest001/2025-10-07/task-ev-003/explainable_variance_map.npy

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Overlaid timecourses: highest vs lowest EV voxels
# ─────────────────────────────────────────────────────────────────────────────
# Time axis in seconds (valid timepoints only)
t_sec = np.arange(time_valid.sum()) * TR

# Find best and worst voxels (nanarg* to skip NaN from 0/0 division)
best_vox = np.nanargmax(ev)
worst_vox = np.nanargmin(ev)

fig, axes = plt.subplots(2, 1, figsize=(12, 6), sharex=True)

# ── Highest EV ───────────────────────────────────────────────────────────────
for rep in range(N_rep):
    axes[0].plot(t_sec, Y_ev[rep, :, best_vox], alpha=0.6, label=f'rep {rep+1}')
axes[0].plot(t_sec, mean_response[:, best_vox], 'k-', lw=2, label='mean')
axes[0].set_ylabel("Intensity")
axes[0].set_title(f"Highest EV voxel  (EV = {ev[best_vox]:.4f})")
axes[0].legend(loc='upper right', ncol=4, fontsize=8)

# ── Lowest EV ────────────────────────────────────────────────────────────────
for rep in range(N_rep):
    axes[1].plot(t_sec, Y_ev[rep, :, worst_vox], alpha=0.6, label=f'rep {rep+1}')
axes[1].plot(t_sec, mean_response[:, worst_vox], 'k-', lw=2, label='mean')
axes[1].set_ylabel("Intensity")
axes[1].set_xlabel("Time (s)")
axes[1].set_title(f"Lowest EV voxel  (EV = {ev[worst_vox]:.4f})")
axes[1].legend(loc='upper right', ncol=4, fontsize=8)

fig.tight_layout()
fig.savefig(BASE / "ev_timecourses_best_worst.png", dpi=150)
plt.show()
