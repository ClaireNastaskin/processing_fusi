# %%
import pandas as pd

# Create a DataFrame with empty columns
df = pd.DataFrame(columns=['run_name', 'sub_Forest001_name'])

df.loc[0, 'run_name'] = 'run-024-20250422-095727-fusi'
df.loc[0, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-rest_run-01'

df.loc[1, 'run_name'] = 'run-026-20250422-100518-fusi'
df.loc[1, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-rest_run-02'

df.loc[2, 'run_name'] = 'run-028-20250422-100859-fusi'
df.loc[2, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-rest_run-03'

df.loc[3, 'run_name'] = 'run-030-20250422-103220-fusi'
df.loc[3, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-movements_run-01'

df.loc[4, 'run_name'] = 'run-033-20250422-110107-fusi'
df.loc[4, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-movements_run-02_chunk-1'

df.loc[5, 'run_name'] = 'run-034-20250422-110410-fusi'
df.loc[5, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-movements_run-02_chunk-2'

df.loc[6, 'run_name'] = 'run-037-20250422-112712-fusi'
df.loc[6, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-movements_run-03_chunk-1'

df.loc[7, 'run_name'] = 'run-039-20250422-113101-fusi'
df.loc[7, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-movements_run-03_chunk-2'

df.loc[8, 'run_name'] = 'run-041-20250422-120112-fusi'
df.loc[8, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-movements_run-04'

df.loc[9, 'run_name'] = 'run-045-20250422-140608-fusi'
df.loc[9, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-motion_run-01'

df.loc[10, 'run_name'] = 'run-060-20250422-145245-fusi'
df.loc[10, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-rest_run-04'

df.loc[11, 'run_name'] = 'run-061-20250422-145509-fusi'
df.loc[11, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-rest_run-05'

df.loc[12, 'run_name'] = 'run-064-20250422-152137-fusi'
df.loc[12, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-movements_run-05'

df.loc[13, 'run_name'] = 'run-076-20250422-155537-fusi'
df.loc[13, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-ecmovements_run-01_acq-train'

df.loc[14, 'run_name'] = 'run-077-20250422-160248-fusi'
df.loc[14, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-ecmovements_run-02_acq-train'

df.loc[15, 'run_name'] = 'run-079-20250422-161715-fusi'
df.loc[15, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250410_task-ecmovements_run-03_acq-test'

df.loc[16, 'run_name'] = 'run-082-20250422-165947-fusi'
df.loc[16, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-audio_run-01'

df.loc[17, 'run_name'] = 'run-084-20250422-172756-fusi'
df.loc[17, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-audiohrf_run-01'

df.loc[18, 'run_name'] = 'run-083-20250422-171234-fusi'
df.loc[18, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-speech_run-01'

df.loc[19, 'run_name'] = 'run-005-20250423-094437-fusi'
df.loc[19, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-emotions_run-01'

df.loc[20, 'run_name'] = 'run-006-20250423-100015-fusi'
df.loc[20, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-emotions_run-02'

df.loc[21, 'run_name'] = 'run-007-20250423-104044-fusi'
df.loc[21, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-emotions_run-03'

df.loc[22, 'run_name'] = 'run-008-20250423-105245-fusi'
df.loc[22, 'sub_Forest001_name'] = 'sub-Forest001_ses-20250422_task-emotions_run-04'


# Save the empty DataFrame to CSV
df.to_csv('/Users/clairenastaskin/data/2025-04-22/correspondance_run_names.csv', index=False)
